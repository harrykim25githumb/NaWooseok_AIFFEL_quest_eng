# %%
# 사각형 넓이를 구하는 클래스 완성!
class Square:
    def __init__(self):
        self.square = int(input('넓이를 구하고 싶은 사각형의 숫자를 써주세요.\n 1.직사각형 2.평행사변형 3.사다리꼴 \n >>>'))

        if self.square == 1:
            print('직사각형 함수는 rect()입니다.')

        elif self.square == 2:
            print('평행사변형 함수는 par()입니다.')
        
        elif self.square == 3:
            print('사다리꼴 함수는 trape()입니다.')
        
        else:
            print('1, 2, 3 중에서 다시 입력해주세요')

    def rect(self):
        width, vertical = map(int, input('가로, 세로를 입력하세요. 예시 : 가로,세로\n >>>').split(','))
        area = width * vertical
        result = '직사각형의 넓이는 : ' + str(area)
        return result

    def par(self):
        lower, vertical = map(int, input('밑변, 높이를 입력하세요. 예시 : 밑변,높이\n >>>').split(','))
        area = lower * vertical
        result = '평행사변형의 넓이는 : ' + str(area)
        return result

    def trape(self):
        lower, upper, height = map(int, input('밑변, 윗변, 높이를 입력하세요. 예시 : 밑변,윗변,높이\n >>>').split(','))
        area = (lower + upper) * height / 2
        result = '사라디꼴의 넓이는 : ' + str(area)
        return result

a = Square()  # 객체 생성 & 2, 3을 각각 입력해 봅시다.
if a.square == 1:
    print(a.rect())
elif a.square == 2:
    print(a.par())
elif a.square == 3:
    print(a.trape())
# Out:
# 넓이를 구하고 싶은 사각형의 숫자를 써주세요.
#  1.직사각형 2.평행사변형 3.사다리꼴
#  >>> 3
# 사다리꼴 함수는 trape()입니다.
# 밑변, 윗변, 높이를 입력하세요. 예시 : 밑변,윗변,높이
#  >>> 2,3,4
# 사라디꼴의 넓이는 : 10.0

# %%
# 문제 3-3. 클래스 업데이트  
# 앞에서 구현했던 메서드들을 Kiosk 클래스에 추가합니다. 직접 코드를 작성해 보세요!
class Kiosk:
    def __init__(self):#일단 여기서 리스트에 메뉴랑 가격 저장해야한다. self를 다는 이유는 class안 다른 메서드에서도 이 리스트를 쓰기위해
        self.menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
        self.price = [2000, 3000, 3000, 2500, 2500, 3000]

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):#메뉴 수만큼 반복할수 있는 반복문 만들고
            print(i+1, self.menu[i], ' : ', self.price[i])#그안에 각 메뉴와 그에맞는 가격을 메뉴수만큼 반복해서 리스트에서 추력 처음에 i+1로 하는 이유는 그냥 보기좋게 1부터하는게 깔끔하니까

    # 주문 메서드
    def menu_select(self,n):
        self.price_sum = self.price[n-1]#price 에서 n이용해서 인덱싱 된값을 다른 메서드에서 쓰기 위해서 self.price_sum으로 다시 저장
        t = 0
        while t != 1 and t != 2: # t가 1과 2가 아닐때만 반복하게해서 temp에 온도 저장
            t = int(input("Hot음료는 1번 Ice음료는 2번을 입력하세요 : "))
            if t == 1:
                self.temp = "Hot"
            elif t == 2:
                self.temp = 'Ice'
            else:
                print('1과 2중 하나로 다시 입력해주세요.\n')
    
    def order(self): # 추가 주문을 위해 만들어준 새로운 매서드
        self.order_menu = []#추가 주문을 했을때 새로 추가된 메뉴를 담기위한 새로운 리스트
        self.order_price = []#이건 가격 리스트

        n = 4444
        while n != 0:# 추가 주문은 받기 위한 반복문 n값에 0일 할당되지 않는 이상 self.menu_select실행됨
            self.menu_print()
            n = int(input("음료 번호를 입력하세요(0: 주문완료) : "))
            if n == 0:# n이 0이면 주문 끝네고
                print("주문이 완료 되었습니다.")
                break
            elif n < 1 or n > len(self.menu):# n이 0도 아니고 주문 메뉴도 아니면 다시 시도
                print("없는 메뉴입니다. 다시 입력해주세요.")
                continue
            
            self.menu_select(n)# menu_select메서드 작동 시키는데 menu에서 order에서 할당받은 n값 쓸수 있게 (n)해줌
            self.order_menu.append(self.temp + ' ' + self.menu[n-1])
            self.order_price.append(self.price[n-1])
            print(self.order_menu)
            print(self.order_price)# 각각 추가된 메뉴들은 order_menu에 새롭게 리스트로 저장 가격도 똑같이

    def pay(self):
        print("지불금액", sum(self.order_price), "원 입니다")# 지불금액은 아까 order메서드에서 새롭게 만든 가격 리스트에 sum()써서 다 더해준거
        c = 0
        while c != 1 and c !=2:# 평범한 카드냐 현금이냐 고르고 그거에 맞게 print
            c = int(input("지불 수단을 현금 또는 카드중에서 선택해주세요(1번: 현금, 2번: 카드) : "))
            if c == 1:
                print("직원을 호출하겠습니다.")
            elif c == 2:
                print("IC칩 방향에 맞게 카드를 꽂아주세요.")
            else:
                print("다시 시도해 주세요")

    def table(self):# 영수증 출력 원래 노드에 예시로 나온거 에서 리스트 부분만 내가 order메서드에서 만들걸로 바꿔 주면됨
        print('⟝' + '-' * 30 + '⟞')
        for i in range(5):
            print('|' + ' ' * 31 + '|')

        for i in range(len(self.order_menu)):
            print(self.order_menu[i], ' : ', self.order_price[i])

        print('합계 금액 :', sum(self.order_price))

        for i in range(5):
            print('|' + ' ' * 31+ '|')
        print('⟝' + '-' * 30 + '⟞')
a = Kiosk()  # 객체 생성 
a.order()  # 주문
a.pay()  # 지불
a.table()  # 주문표 출력
# Out:
# 1 americano  :  2000
# 2 latte  :  3000
# 3 mocha  :  3000
# 4 yuza_tea  :  2500
# 5 green_tea  :  2500
# 6 choco_latte  :  3000
# 음료 번호를 입력하세요(0: 주문완료) :  5
# Hot음료는 1번 Ice음료는 2번을 입력하세요 :  1
# ['Hot green_tea']
# [2500]
# 1 americano  :  2000
# 2 latte  :  3000
# 3 mocha  :  3000
# 4 yuza_tea  :  2500
# 5 green_tea  :  2500
# 6 choco_latte  :  3000
# 음료 번호를 입력하세요(0: 주문완료) :  1
# Hot음료는 1번 Ice음료는 2번을 입력하세요 :  2
# ['Hot green_tea', 'Ice americano']
# [2500, 2000]
# 1 americano  :  2000
# 2 latte  :  3000
# 3 mocha  :  3000
# 4 yuza_tea  :  2500
# 5 green_tea  :  2500
# 6 choco_latte  :  3000
# 음료 번호를 입력하세요(0: 주문완료) :  89
# 없는 메뉴입니다. 다시 입력해주세요.
# 1 americano  :  2000
# 2 latte  :  3000
# 3 mocha  :  3000
# 4 yuza_tea  :  2500
# 5 green_tea  :  2500
# 6 choco_latte  :  3000
# 음료 번호를 입력하세요(0: 주문완료) :  0
# 주문이 완료 되었습니다.
# 지불금액 4500 원 입니다
# 지불 수단을 현금 또는 카드중에서 선택해주세요(1번: 현금, 2번: 카드) :  2
# IC칩 방향에 맞게 카드를 꽂아주세요.
# ⟝------------------------------⟞
# |                               |
# ...
